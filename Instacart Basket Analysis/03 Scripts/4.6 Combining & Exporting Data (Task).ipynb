# %%
# import libraries
import pandas as pd
import numpy as np
import os

# %%
#  import the orders_products_combined dataframe from the pickle file you just saved

df_orders_products_combined= pd.read_pickle(r'C:\Users\Asus\Instacart Basket Analysis\02 Data\Prepared Data\orders_products_combined.pkl')

# %%
#Check the head of the new datframe
df_orders_products_combined.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2539329        1             1                   2                  8
# 2   2539329        1             1                   2                  8
# 3   2539329        1             1                   2                  8
# 4   2539329        1             1                   2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge
# 0                     NaN         196                  1          0   both
# 1                     NaN       14084                  2          0   both
# 2                     NaN       12427                  3          0   both
# 3                     NaN       26088                  4          0   both
# 4                     NaN       26405                  5          0   both

# %%
#Check the shape of the df_orders_products_combined
df_orders_products_combined.shape
# Out:
# (32434489, 10)

# %%
#Drop column merge 
df_orders_products_combined.drop(columns='_merge', inplace=True)
df_orders_products_combined
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2539329        1             1                   2
# 2          2539329        1             1                   2
# 3          2539329        1             1                   2
# 4          2539329        1             1                   2
# ...            ...      ...           ...                 ...
# 32434484   2977660   206209            13                   1
# 32434485   2977660   206209            13                   1
# 32434486   2977660   206209            13                   1
# 32434487   2977660   206209            13                   1
# 32434488   2977660   206209            13                   1
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         8                     NaN       14084
# ...

# %%
#import product dataset which has no duplicates and clean dataset
df_prods= pd.read_csv(r'C:\Users\Asus\Instacart Basket Analysis\02 Data\Prepared Data\products_checked.csv', index_col = False)
df_prods.head()
df_prods.drop(columns=['Unnamed: 0'], inplace= True)

# %%
#Check the top 5 data
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
#merge Product dataset and orders_products_combined
df_orders_products_merged=df_orders_products_combined.merge(df_prods, on ='product_id', indicator= True)

# %%
df_orders_products_merged
# Out:
#           order_id  user_id  order_number  orders_day_of_week  \
# 0          2539329        1             1                   2
# 1          2398795        1             2                   3
# 2           473747        1             3                   3
# 3          2254736        1             4                   4
# 4           431534        1             5                   4
# ...            ...      ...           ...                 ...
# 32404854   1320836   202557            17                   2
# 32404855     31526   202557            18                   5
# 32404856    758936   203436             1                   2
# 32404857   2745165   203436             2                   3
# 32404858   3093936   205420             1                   4
#
#           order_hour_of_day  days_since_prior_order  product_id  \
# 0                         8                     NaN         196
# 1                         7                    15.0         196
# ...

# %%
# shape of df_orders_products_merged
df_orders_products_merged.shape
# Out:
# (32404859, 14)

# %%
#Export the merged file in pickle format as “orders_products_combined.pkl”

path= r'C:\Users\Asus\Instacart Basket Analysis\02 Data\Prepared Data'
path
# Out:
# 'C:\\Users\\Asus\\Instacart Basket Analysis\\02 Data\\Prepared Data'

# %%
df_orders_products_merged.to_pickle(os.path.join(path,'orders_products_merged.pkl'))
